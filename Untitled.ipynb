# %%
import numpy as np

# %%
label_list = np.loadtxt("ILSVRC2012_validation_ground_truth.txt")

# %%
list_label = []
for i in label_list:
    list_label.append(int(i))

# %%
list_label = np.array(list_label)
num = (list_label==1)
print(num.sum())
# Out:
# 50

# %%
h = "abc"
len(h)
# Out:
# 3

# %%
for i,j in enumerate(label_list):
    name_len = 8 - len(str(i+1))
    name = name_len * "0"
    print(name+str(i+1))
#     if i ==1000:
#         break
# Out:
# 00000001
# 00000002
# 00000003
# 00000004
# 00000005
# 00000006
# 00000007
# 00000008
# 00000009
# 00000010
# 00000011
# 00000012
# 00000013
# 00000014
# 00000015
# 00000016
# 00000017
# 00000018
# 00000019
# 00000020
# 00000021
# 00000022
# 00000023
# 00000024
# 00000025
# 00000026
# 00000027
# 00000028
# 00000029
# 00000030
# 00000031
# 00000032
# 00000033
# 00000034
# 00000035
# 00000036
# 00000037
# 00000038
# 00000039
# 00000040
# 00000041
# 00000042
# 00000043
# 00000044
# 00000045
# 00000046
# 00000047
# 00000048
# 00000049
# 00000050
# 00000051
# 00000052
# 00000053
# 00000054
# 00000055
# 00000056
# 00000057
# 00000058
# 00000059
# 00000060
# 00000061
# 00000062
# 00000063
# 00000064
# 00000065
# 00000066
# 00000067
# 00000068
# 00000069
# 00000070
# 00000071
# 00000072
# 00000073
# 00000074
# 00000075
# 00000076
# 00000077
# 00000078
# 00000079
# 00000080
# 00000081
# 00000082
# 00000083
# 00000084
# 00000085
# 00000086
# 00000087
# 00000088
# 00000089
# 00000090
# ...

# %%
a = []

# %%
b=np.array([[2,3],[3,4]])

# %%
a.append(b)

# %%
a
# Out:
# [array([[2, 3],
#         [3, 4]])]

# %%
type(a)
# Out:
# list

# %%
type(a)
# Out:
# list

# %%
len(a)
# Out:
# 1

# %%
h=np.array([[2,3],[3,4]])

# %%
a.append(h)

# %%
len(a)
# Out:
# 2
